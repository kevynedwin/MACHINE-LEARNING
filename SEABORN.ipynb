# %%
import seaborn as sns
# %matplotlib inline

# %%
tips= sns.load_dataset('tips')

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
tips.max()
# Out:
# total_bill    50.81
# tip              10
# sex            Male
# smoker          Yes
# day            Thur
# time          Lunch
# size              6
# dtype: object

# %%
tips.sex.value_counts(normalize=True) #changing to percentage
# Out:
# Male      0.643443
# Female    0.356557
# Name: sex, dtype: float64

# %%
tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips.time.unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
tips.time.value_counts(normalize=True)
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %% [markdown]
# # Visualisation using distplot (distributions)

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
sns.distplot(tips['total_bill'],kde=True,bins=30)

# %% [markdown]
# ## joinpoint

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.pairplot(tips)

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])

# %%
tips.total_bill.isnull().sum()
# Out:
# 0

# %%
sns.rugplot(tips['tip'])

# %% [markdown]
# # GRID

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.PairGrid(iris)

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g=sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)#map to upper,lower and diagonal
g.map_lower(sns.kdeplot)

# %%
sns.pairplot(iris)

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris,hue='species',palette='rainbow')

# %%
#just the Grid

# %%
tips.smoker.unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
tips.smoker.unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
g=sns.FacetGrid(tips,col='time',row='smoker')

# %%
g=sns.FacetGrid(tips,col='time',row='smoker')
g=g.map(plt.hist,'total_bill')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips= sns.load_dataset('tips')
g=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
g.map(plt.scatter,'total_bill','tip').add_legend()

# %% [markdown]
# # JointGrid

# %%
g=sns.JointGrid(x='total_bill',y='tip',data=tips)
g=g.plot(sns.regplot,sns.distplot)

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
pvflights=flights.pivot_table(values='passengers',index='month',columns='year')

# %%
sns.heatmap(pvflights)

# %%
sns.heatmap(pvflights,cmap='magma',linecolor='white',linewidths=1)

# %% [markdown]
# ## Cluster map

# %%
sns.clustermap(pvflights) #information grouped by passenger count

# %%
sns.clustermap(pvflights,cmap='coolwarm',standard_scale=1)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
